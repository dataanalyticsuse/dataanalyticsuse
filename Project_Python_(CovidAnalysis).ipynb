# %% [markdown]
# # 1.Understanding the Data:

# %% [markdown]
# Import necessary libraries (e.g., pandas, matplotlib, seaborn).<br>
# Load the COVID-19 dataset.<br>
# Display basic information about the dataset (e.g., data types, missing values).<br>

# %%
# load required libraries/modules
import pandas as pd
# Load the dataset
covid=pd.read_csv(r"C:\Users\mypc\Downloads\covid_19_data.csv")
covid
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 0           1/22/2020 17:00        1.0     0.0        0.0
# 1           1/22/2020 17:00       14.0     0.0        0.0
# 2           1/22/2020 17:00        6.0     0.0        0.0
# 3           1/22/2020 17:00        1.0     0.0        0.0
# 4           1/22/2020 17:00        0.0     0.0        0.0
# ...                     ...        ...     ...        ...
# 306424  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428  2021-05-30 04:20:55   391559.0  4252.0        0.0
#
# [306429 rows x 8 columns]

# %%
# Display basic information about the dataset
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
# buttom values
covid.tail()
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 306424  306425      05/29/2021  Zaporizhia Oblast         Ukraine
# 306425  306426      05/29/2021            Zeeland     Netherlands
# 306426  306427      05/29/2021           Zhejiang  Mainland China
# 306427  306428      05/29/2021    Zhytomyr Oblast         Ukraine
# 306428  306429      05/29/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed  Deaths  Recovered
# 306424  2021-05-30 04:20:55   102641.0  2335.0    95289.0
# 306425  2021-05-30 04:20:55    29147.0   245.0        0.0
# 306426  2021-05-30 04:20:55     1364.0     1.0     1324.0
# 306427  2021-05-30 04:20:55    87550.0  1738.0    83790.0
# 306428  2021-05-30 04:20:55   391559.0  4252.0        0.0

# %%
# data types
covid.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %%
# missing values
covid.isna().sum()
# Out:
# SNo                    0
# ObservationDate        0
# Province/State     78103
# Country/Region         0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %%
# rows and columns
covid.shape
# Out:
# (306429, 8)

# %%
# columns Name
covid.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %% [markdown]
# # 2. Data Cleaning:

# %%
Handle missing values.
Convert data types if necessary.
Check for duplicates.

# %%
# Handle missing values
covid.dropna(inplace=True)

# %%
covid.isna().sum()
# Out:
# SNo                0
# ObservationDate    0
# Province/State     0
# Country/Region     0
# Last Update        0
# Confirmed          0
# Deaths             0
# Recovered          0
# dtype: int64

# %%
# Convert data types if necessary ( ObservationDate    datetime64[ns]) change to datetime

covid['ObservationDate'] = pd.to_datetime(covid['ObservationDate'])
covid['ObservationDate']
# Out:
# 0        2020-01-22
# 1        2020-01-22
# 2        2020-01-22
# 3        2020-01-22
# 4        2020-01-22
#             ...
# 306424   2021-05-29
# 306425   2021-05-29
# 306426   2021-05-29
# 306427   2021-05-29
# 306428   2021-05-29
# Name: ObservationDate, Length: 228326, dtype: datetime64[ns]

# %%
# Check for duplicates
print("Number of duplicates:", covid.duplicated().sum())
# Out:
# Number of duplicates: 0

# %% [markdown]
# # 3. Descriptive Statistics:

# %% [markdown]
# Generate descriptive statistics (mean, median, min, max) for numeric columns.<br>
# Explore summary statistics for categorical columns.

# %%
# Descriptive statistics
print(covid.describe())

# Summary statistics for categorical columns
print(covid['Country/Region'].value_counts())
# Out:
#                  SNo                ObservationDate     Confirmed  \
# count  228326.000000                         228326  2.283260e+05
# mean   158732.777113  2020-11-14 03:17:45.686780928  8.021381e+04
# min         1.000000            2020-01-22 00:00:00 -3.028440e+05
# 25%     85431.250000            2020-08-11 00:00:00  1.225000e+03
# 50%    159305.500000            2020-11-18 00:00:00  1.175750e+04
# 75%    232835.750000            2021-02-22 00:00:00  4.841125e+04
# max    306429.000000            2021-05-29 00:00:00  5.713215e+06
# std     85862.065298                            NaN  2.493661e+05
#
#               Deaths     Recovered
# count  228326.000000  2.283260e+05
# mean     1961.373273  4.184345e+04
# min      -178.000000 -8.544050e+05
# 25%        15.000000  0.000000e+00
# 50%       234.000000  1.211000e+03
# 75%      1411.000000  1.660275e+04
# max    112385.000000  6.399531e+06
# std      5871.937048  1.793670e+05
# Country/Region
# Russia            30129
# US                26740
# Japan             17932
# Mainland China    15758
# India             13050
# Colombia          12419
# Mexico            12199
# Brazil            10144
# Ukraine            9801
# Peru               9542
# Italy              8001
# Spain              7615
# Sweden             7539
# Canada             6960
# UK                 6553
# Germany            6481
# Chile              6375
# Netherlands        5864
# France             4544
# Australia          3785
# Pakistan           2478
# Belgium            2388
# Denmark             893
# Hong Kong           494
# Macau               494
# Taiwan               49
# China                48
# Others               46
# Israel                5
# Name: count, dtype: int64

# %% [markdown]
# # 4. Time Series Analysis:

# %% [markdown]
# Analyze the trends in confirmed, deaths, and recovered cases over time.<br>
# Create time-based visualizations.

# %%
# Time series analysis
# groupby 'ObservationDate' and apply aggregation functions like sum on deaths,confirmed ,recovered 
# df_time = df.groupby('ObservationDate').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})

covid_time=covid.groupby('ObservationDate').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})
covid_time
# Out:
#                    Confirmed     Deaths   Recovered
# ObservationDate
# 2020-01-22             550.0       17.0        28.0
# 2020-01-23            1088.0       34.0        58.0
# 2020-01-24             925.0       26.0        36.0
# 2020-01-25            1411.0       42.0        39.0
# 2020-01-26            2085.0       56.0        49.0
# ...                      ...        ...         ...
# 2021-05-25       115693206.0  2470982.0  63714612.0
# 2021-05-26       116092305.0  2480596.0  64130135.0
# 2021-05-27       116466022.0  2490458.0  64673366.0
# 2021-05-28       116794539.0  2499270.0  65077386.0
# 2021-05-29       117126160.0  2507182.0  65438252.0
#
# [494 rows x 3 columns]

# %%
# Plot time series data using line plot

import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,10))
sns.lineplot(data=covid_time, x='ObservationDate', y='Confirmed', label='Confirmed')
sns.lineplot(data=covid_time, x='ObservationDate', y='Deaths', label='Deaths')
sns.lineplot(data=covid_time, x='ObservationDate', y='Recovered', label='Recovered')
plt.title('COVID-19 Time Series Analysis')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 5. Geographical Analysis:

# %% [markdown]
# Analyze the distribution of cases across different countries/regions.<br>
# Create geographical visualizations (e.g., world map).

# %%
# Geographical analysis
# df_country = df.groupby('Country/Region').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})

covid_country = covid.groupby('Country/Region').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})
covid_country
# Out:
#                    Confirmed       Deaths     Recovered
# Country/Region
# Australia       9.447430e+06     268435.0  7.219933e+06
# Belgium         1.547341e+08    4219275.0  0.000000e+00
# Brazil          2.649295e+09   72339029.0  2.311993e+09
# Canada          1.934975e+08    5692896.0  1.715769e+08
# Chile           2.315812e+08    5707664.0  2.166768e+08
# China           0.000000e+00          0.0  0.000000e+00
# Colombia        5.148170e+08   13962927.0  4.686380e+08
# Denmark         2.122260e+05        186.0  1.929090e+05
# France          1.918464e+07     157809.0  9.383745e+06
# Germany         5.174361e+08   13150115.0  4.493167e+08
# Hong Kong       2.655935e+06      45325.0  2.433578e+06
# India           3.221090e+09   44256013.0  2.898258e+09
# Israel          5.000000e+00          0.0  0.000000e+00
# Italy           6.277543e+08   24852224.0  4.851544e+08
# Japan           8.866606e+07    1555677.0  7.805405e+07
# Macau           2.060500e+04          0.0  1.913000e+04
# Mainland China  4.082260e+07    2089872.0  3.689744e+07
# Mexico          4.595573e+08   42918161.0  3.612402e+08
# Netherlands     2.304008e+08    3616057.0  3.295280e+06
# Others          2.622800e+04        189.0  5.003000e+03
# Pakistan        1.632456e+08    3489065.0  1.453124e+08
# Peru            3.584896e+08   13119233.0  3.227364e+08
# Russia          9.211500e+08   18271229.0  7.883275e+08
# Spain           6.401320e+08   18124340.0  5.727280e+07
# Sweden          1.407718e+08    3167242.0  0.000000e+00
# Taiwan          1.104000e+03         24.0  1.890000e+02
# UK              7.705376e+08   27316263.0  2.323781e+06
# US              6.049146e+09  123303762.0  5.033710e+08
# Ukraine         3.102261e+08    6209502.0  2.342478e+08

# %%
# Plot geographical data
# sns.barplot(x=df_country.index, y='Confirmed', data=df_country)


plt.figure(figsize=(14,6))
sns.barplot(x=covid_country.index, y='Confirmed', data=covid_country)
sns.barplot(x=covid_country.index, y='Deaths', data=covid_country)
sns.barplot(x=covid_country.index, y='Recovered', data=covid_country)
plt.title('COVID-19 Time Series Analysis')
plt.xlabel('Country')
plt.ylabel('Cases')
plt.xticks(rotation=90, ha='center')
plt.show()

# %% [markdown]
# # 6. Correlation Analysis:

# %% [markdown]
# Examine the correlation between different numeric variables.

# %%
# Correlation analysis between confirmed,deaths and recovered

Correlation_analysis =covid[["Confirmed","Deaths","Recovered"]].corr()
Correlation_analysis
# Out:
#            Confirmed    Deaths  Recovered
# Confirmed   1.000000  0.881104   0.498839
# Deaths      0.881104  1.000000   0.421545
# Recovered   0.498839  0.421545   1.000000

# %%
# Plot correlation on heat map
sns.heatmap(Correlation_analysis, annot=True,fmt=".2f")
plt.title("Correlation_analysis")
# Out:
# Text(0.5, 1.0, 'Correlation_analysis')

# %% [markdown]
# # 7. Advanced Analysis:

# %% [markdown]
# Explore advanced visualizations or statistical tests based on the specific questions you want to answer.

# %%
# Calculate the total number of confirmed cases, deaths, and recoveries for each country/region
covid_country_region = covid.groupby('Country/Region').agg({'Confirmed': 'sum', 'Deaths': 'sum', 'Recovered': 'sum'})
covid_country_region
# Out:
#                    Confirmed       Deaths     Recovered
# Country/Region
# Australia       9.447430e+06     268435.0  7.219933e+06
# Belgium         1.547341e+08    4219275.0  0.000000e+00
# Brazil          2.649295e+09   72339029.0  2.311993e+09
# Canada          1.934975e+08    5692896.0  1.715769e+08
# Chile           2.315812e+08    5707664.0  2.166768e+08
# China           0.000000e+00          0.0  0.000000e+00
# Colombia        5.148170e+08   13962927.0  4.686380e+08
# Denmark         2.122260e+05        186.0  1.929090e+05
# France          1.918464e+07     157809.0  9.383745e+06
# Germany         5.174361e+08   13150115.0  4.493167e+08
# Hong Kong       2.655935e+06      45325.0  2.433578e+06
# India           3.221090e+09   44256013.0  2.898258e+09
# Israel          5.000000e+00          0.0  0.000000e+00
# Italy           6.277543e+08   24852224.0  4.851544e+08
# Japan           8.866606e+07    1555677.0  7.805405e+07
# Macau           2.060500e+04          0.0  1.913000e+04
# Mainland China  4.082260e+07    2089872.0  3.689744e+07
# Mexico          4.595573e+08   42918161.0  3.612402e+08
# Netherlands     2.304008e+08    3616057.0  3.295280e+06
# Others          2.622800e+04        189.0  5.003000e+03
# Pakistan        1.632456e+08    3489065.0  1.453124e+08
# Peru            3.584896e+08   13119233.0  3.227364e+08
# Russia          9.211500e+08   18271229.0  7.883275e+08
# Spain           6.401320e+08   18124340.0  5.727280e+07
# Sweden          1.407718e+08    3167242.0  0.000000e+00
# Taiwan          1.104000e+03         24.0  1.890000e+02
# UK              7.705376e+08   27316263.0  2.323781e+06
# US              6.049146e+09  123303762.0  5.033710e+08
# Ukraine         3.102261e+08    6209502.0  2.342478e+08

# %%
# Identify the countries/regions with the highest number of confirmed cases, deaths, and recoveries.
Highest_number = covid.sort_values(by=['Country/Region','Confirmed','Deaths','Recovered'],ascending=False)
Highest_number
# Out:
#            SNo ObservationDate                Province/State Country/Region  \
# 306083  306084      2021-05-29                          Kiev        Ukraine
# 305318  305319      2021-05-28                          Kiev        Ukraine
# 304553  304554      2021-05-27                          Kiev        Ukraine
# 303788  303789      2021-05-26                          Kiev        Ukraine
# 303023  303024      2021-05-25                          Kiev        Ukraine
# ...        ...             ...                           ...            ...
# 7115      7116      2020-03-19  Diamond Princess cruise ship      Australia
# 7416      7417      2020-03-20  Diamond Princess cruise ship      Australia
# 7722      7723      2020-03-21  Diamond Princess cruise ship      Australia
# 7925      7926      2020-03-22          External territories      Australia
# 7956      7957      2020-03-22          Jervis Bay Territory      Australia
#
#                 Last Update  Confirmed  Deaths  Recovered
# 306083  2021-05-30 04:20:55   206278.0  5076.0   163588.0
# 305318  2021-05-29 04:20:41   205901.0  5070.0   161908.0
# 304553  2021-05-28 04:20:36   205517.0  5055.0   157728.0
# 303788  2021-05-27 04:20:59   205063.0  5044.0   154532.0
# 303023  2021-05-26 04:20:35   204678.0  5035.0   150195.0
# ...                     ...        ...     ...        ...
# 7115    2020-03-14T02:33:04        0.0     0.0        0.0
# 7416    2020-03-14T02:33:04        0.0     0.0        0.0
# 7722    2020-03-14T02:33:04        0.0     0.0        0.0
# 7925            3/8/20 5:31        0.0     0.0        0.0
# 7956            3/8/20 5:31        0.0     0.0        0.0
#
# [228326 rows x 8 columns]

# %%
# Visualize the distribution of deaths using bar chart

covid_death = covid.groupby('Country/Region').agg({'Deaths': 'max'})
covid_death
# Out:
#                                 Deaths
# Country/Region
#  Azerbaijan                        0.0
# ('St. Martin',)                    0.0
# Afghanistan                     2899.0
# Albania                         2449.0
# Algeria                         3460.0
# ...                                ...
# West Bank and Gaza              3492.0
# Yemen                           1319.0
# Zambia                          1276.0
# Zimbabwe                        1594.0
# occupied Palestinian territory     0.0
#
# [229 rows x 1 columns]

# %%
sns.barplot(covid_death)
# Out:
# <Axes: >
